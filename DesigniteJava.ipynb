# %%
import subprocess
from pathlib import Path
import logging
from datetime import datetime

CLONED_REPOS_PATH = Path("E:\\Repositories\\Cloned_Reposit")
OUTPUT_BASE_PATH = Path("E:\\Repositories\\Summary_Analysis")
DESIGNITE_JAR_PATH = Path("E:\\DesigniteJava\\DesigniteJava.jar") 

LOG_FILE = Path.cwd() / f"process_repositories_{datetime.now().strftime('%Y%m%d_%H%M%S')}.log"

PARALLEL_PROCESSES = 1 

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s",
    handlers=[
        logging.FileHandler(LOG_FILE),
        logging.StreamHandler()
    ]
)


def verify_paths():
    """
    Verify that essential paths exist.
    """
    if not CLONED_REPOS_PATH.exists() or not CLONED_REPOS_PATH.is_dir():
        logging.error(f"Cloned repositories path does not exist or is not a directory: {CLONED_REPOS_PATH}")
        return False

    if not DESIGNITE_JAR_PATH.exists() or not DESIGNITE_JAR_PATH.is_file():
        logging.error(f"DesigniteJava.jar not found at path: {DESIGNITE_JAR_PATH}")
        return False

    # Create output base directory if it doesn't exist
    if not OUTPUT_BASE_PATH.exists():
        try:
            OUTPUT_BASE_PATH.mkdir(parents=True, exist_ok=True)
            logging.info(f"Created output base directory: {OUTPUT_BASE_PATH}")
        except Exception as e:
            logging.error(f"Failed to create output base directory: {e}")
            return False

    return True

def get_repositories():
    """
    Get all repository directories under the cloned repositories path.
    """
    repos = [repo for repo in CLONED_REPOS_PATH.iterdir() if repo.is_dir()]
    logging.info(f"Found {len(repos)} repositories in {CLONED_REPOS_PATH}")
    return repos

def create_output_directory(repo_name):
    """
    Create an output directory for the given repository.
    """
    output_dir = OUTPUT_BASE_PATH / repo_name
    if not output_dir.exists():
        try:
            output_dir.mkdir(parents=True, exist_ok=True)
            logging.info(f"Created output directory: {output_dir}")
        except Exception as e:
            logging.error(f"Failed to create output directory for {repo_name}: {e}")
            return None
    else:
        logging.info(f"Output directory already exists: {output_dir}")
    return output_dir

def run_designite(repo_path, output_path):
    """
    Run the DesigniteJava.jar command for the given repository.
    """
    command = [
        "java",
        "-jar",
        str(DESIGNITE_JAR_PATH),
        "-i",
        str(repo_path),
        "-o",
        str(output_path)
    ]
    repo_name = repo_path.name
    logging.info(f"Processing repository: {repo_name}")
    logging.info(f"Executing command: {' '.join(command)}")

    try:
        result = subprocess.run(
            command,
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE,
            text=True,
            check=True
        )
        logging.info(f"Successfully processed: {repo_name}")
        # Optionally, log the output from DesigniteJava.jar
        # logging.debug(result.stdout)
    except subprocess.CalledProcessError as e:
        logging.error(f"DesigniteJava returned a non-zero exit code for {repo_name}: {e.returncode}")
        logging.error(f"Error output: {e.stderr}")
    except Exception as e:
        logging.error(f"Failed to process {repo_name}: {e}")

def process_repositories_sequentially(repos):
    """
    Process repositories one by one.
    """
    for repo in repos:
        repo_name = repo.name
        output_dir = create_output_directory(repo_name)
        if output_dir:
            run_designite(repo, output_dir)

def process_repositories_in_parallel(repos, max_workers=4):
    """
    Process repositories in parallel using multiprocessing.
    """
    from concurrent.futures import ThreadPoolExecutor, as_completed

    def process_single_repo(repo):
        repo_name = repo.name
        output_dir = create_output_directory(repo_name)
        if output_dir:
            run_designite(repo, output_dir)

    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        future_to_repo = {executor.submit(process_single_repo, repo): repo for repo in repos}
        for future in as_completed(future_to_repo):
            repo = future_to_repo[future]
            try:
                future.result()
            except Exception as exc:
                logging.error(f"Repository {repo.name} generated an exception: {exc}")


def main():
    logging.info("=== Starting Processing of Java Repositories ===")

    if not verify_paths():
        logging.error("Verification of paths failed. Exiting.")
        return

    repositories = get_repositories()

    if not repositories:
        logging.info("No repositories found to process. Exiting.")
        return

    if PARALLEL_PROCESSES > 1:
        logging.info(f"Processing repositories in parallel with {PARALLEL_PROCESSES} workers.")
        process_repositories_in_parallel(repositories, max_workers=PARALLEL_PROCESSES)
    else:
        logging.info("Processing repositories sequentially.")
        process_repositories_sequentially(repositories)

    logging.info("=== All repositories have been processed. ===")


main()
# Out:
# 2024-09-20 15:12:45,877 - INFO - === Starting Processing of Java Repositories ===
# 2024-09-20 15:12:45,901 - INFO - Created output base directory: E:\Repositories\Summary_Analysis
# 2024-09-20 15:12:46,115 - INFO - Found 100 repositories in E:\Repositories\Cloned_Reposit
# 2024-09-20 15:12:46,117 - INFO - Processing repositories sequentially.
# 2024-09-20 15:12:46,120 - INFO - Created output directory: E:\Repositories\Summary_Analysis\abtin_bigdata
# 2024-09-20 15:12:46,125 - INFO - Processing repository: abtin_bigdata
# 2024-09-20 15:12:46,130 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\abtin_bigdata -o E:\Repositories\Summary_Analysis\abtin_bigdata
# 2024-09-20 15:12:58,557 - INFO - Successfully processed: abtin_bigdata
# 2024-09-20 15:12:58,560 - INFO - Created output directory: E:\Repositories\Summary_Analysis\acl9es_GhostHunter
# 2024-09-20 15:12:58,562 - INFO - Processing repository: acl9es_GhostHunter
# 2024-09-20 15:12:58,565 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\acl9es_GhostHunter -o E:\Repositories\Summary_Analysis\acl9es_GhostHunter
# 2024-09-20 15:13:07,094 - INFO - Successfully processed: acl9es_GhostHunter
# 2024-09-20 15:13:07,197 - INFO - Created output directory: E:\Repositories\Summary_Analysis\AdaptiveSystem_finalproject
# 2024-09-20 15:13:07,200 - INFO - Processing repository: AdaptiveSystem_finalproject
# 2024-09-20 15:13:07,205 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\AdaptiveSystem_finalproject -o E:\Repositories\Summary_Analysis\AdaptiveSystem_finalproject
# 2024-09-20 15:13:24,977 - INFO - Successfully processed: AdaptiveSystem_finalproject
# 2024-09-20 15:13:24,982 - INFO - Created output directory: E:\Repositories\Summary_Analysis\AlexAbraham1_YUClubs
# 2024-09-20 15:13:24,985 - INFO - Processing repository: AlexAbraham1_YUClubs
# 2024-09-20 15:13:24,987 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\AlexAbraham1_YUClubs -o E:\Repositories\Summary_Analysis\AlexAbraham1_YUClubs
# 2024-09-20 15:13:45,405 - INFO - Successfully processed: AlexAbraham1_YUClubs
# 2024-09-20 15:13:45,411 - INFO - Created output directory: E:\Repositories\Summary_Analysis\alexoro_android-root-device-detector
# 2024-09-20 15:13:45,413 - INFO - Processing repository: alexoro_android-root-device-detector
# 2024-09-20 15:13:45,413 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\alexoro_android-root-device-detector -o E:\Repositories\Summary_Analysis\alexoro_android-root-device-detector
# 2024-09-20 15:13:52,749 - INFO - Successfully processed: alexoro_android-root-device-detector
# 2024-09-20 15:13:52,752 - INFO - Created output directory: E:\Repositories\Summary_Analysis\alexyem0222_amazon
# 2024-09-20 15:13:52,754 - INFO - Processing repository: alexyem0222_amazon
# 2024-09-20 15:13:52,758 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\alexyem0222_amazon -o E:\Repositories\Summary_Analysis\alexyem0222_amazon
# 2024-09-20 15:14:04,257 - INFO - Successfully processed: alexyem0222_amazon
# 2024-09-20 15:14:04,260 - INFO - Created output directory: E:\Repositories\Summary_Analysis\AppFactoryOrg_app-factory
# 2024-09-20 15:14:04,262 - INFO - Processing repository: AppFactoryOrg_app-factory
# 2024-09-20 15:14:04,262 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\AppFactoryOrg_app-factory -o E:\Repositories\Summary_Analysis\AppFactoryOrg_app-factory
# 2024-09-20 15:14:09,586 - INFO - Successfully processed: AppFactoryOrg_app-factory
# 2024-09-20 15:14:09,594 - INFO - Created output directory: E:\Repositories\Summary_Analysis\bbemis017_StudentManagement
# 2024-09-20 15:14:09,597 - INFO - Processing repository: bbemis017_StudentManagement
# 2024-09-20 15:14:09,602 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\bbemis017_StudentManagement -o E:\Repositories\Summary_Analysis\bbemis017_StudentManagement
# 2024-09-20 15:14:22,073 - INFO - Successfully processed: bbemis017_StudentManagement
# 2024-09-20 15:14:22,078 - INFO - Created output directory: E:\Repositories\Summary_Analysis\bobanpaul_MySampleProject
# 2024-09-20 15:14:22,085 - INFO - Processing repository: bobanpaul_MySampleProject
# 2024-09-20 15:14:22,087 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\bobanpaul_MySampleProject -o E:\Repositories\Summary_Analysis\bobanpaul_MySampleProject
# 2024-09-20 15:14:29,607 - INFO - Successfully processed: bobanpaul_MySampleProject
# 2024-09-20 15:14:29,607 - INFO - Created output directory: E:\Repositories\Summary_Analysis\BrassGoggledCoders_FantasyKingdoms
# 2024-09-20 15:14:29,609 - INFO - Processing repository: BrassGoggledCoders_FantasyKingdoms
# 2024-09-20 15:14:29,613 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\BrassGoggledCoders_FantasyKingdoms -o E:\Repositories\Summary_Analysis\BrassGoggledCoders_FantasyKingdoms
# 2024-09-20 15:14:47,557 - INFO - Successfully processed: BrassGoggledCoders_FantasyKingdoms
# 2024-09-20 15:14:47,562 - INFO - Created output directory: E:\Repositories\Summary_Analysis\brotherBear_aor-java-neo
# 2024-09-20 15:14:47,565 - INFO - Processing repository: brotherBear_aor-java-neo
# 2024-09-20 15:14:47,567 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\brotherBear_aor-java-neo -o E:\Repositories\Summary_Analysis\brotherBear_aor-java-neo
# 2024-09-20 15:14:56,850 - INFO - Successfully processed: brotherBear_aor-java-neo
# 2024-09-20 15:14:56,855 - INFO - Created output directory: E:\Repositories\Summary_Analysis\bsergent_RealMail
# 2024-09-20 15:14:56,857 - INFO - Processing repository: bsergent_RealMail
# 2024-09-20 15:14:56,859 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\bsergent_RealMail -o E:\Repositories\Summary_Analysis\bsergent_RealMail
# 2024-09-20 15:15:05,200 - INFO - Successfully processed: bsergent_RealMail
# 2024-09-20 15:15:05,207 - INFO - Created output directory: E:\Repositories\Summary_Analysis\btokumi15_btokumi-SecretCode
# 2024-09-20 15:15:05,209 - INFO - Processing repository: btokumi15_btokumi-SecretCode
# 2024-09-20 15:15:05,212 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\btokumi15_btokumi-SecretCode -o E:\Repositories\Summary_Analysis\btokumi15_btokumi-SecretCode
# 2024-09-20 15:15:11,987 - INFO - Successfully processed: btokumi15_btokumi-SecretCode
# 2024-09-20 15:15:11,990 - INFO - Created output directory: E:\Repositories\Summary_Analysis\buremba_netty-rest
# 2024-09-20 15:15:11,992 - INFO - Processing repository: buremba_netty-rest
# 2024-09-20 15:15:11,995 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\buremba_netty-rest -o E:\Repositories\Summary_Analysis\buremba_netty-rest
# 2024-09-20 15:15:24,891 - INFO - Successfully processed: buremba_netty-rest
# 2024-09-20 15:15:24,920 - INFO - Created output directory: E:\Repositories\Summary_Analysis\butlersrepos_dungeon-digger
# 2024-09-20 15:15:24,920 - INFO - Processing repository: butlersrepos_dungeon-digger
# 2024-09-20 15:15:24,920 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\butlersrepos_dungeon-digger -o E:\Repositories\Summary_Analysis\butlersrepos_dungeon-digger
# 2024-09-20 15:15:55,029 - INFO - Successfully processed: butlersrepos_dungeon-digger
# 2024-09-20 15:15:55,034 - INFO - Created output directory: E:\Repositories\Summary_Analysis\bweisiger15_Tic-Tac-Toe
# 2024-09-20 15:15:55,037 - INFO - Processing repository: bweisiger15_Tic-Tac-Toe
# 2024-09-20 15:15:55,040 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\bweisiger15_Tic-Tac-Toe -o E:\Repositories\Summary_Analysis\bweisiger15_Tic-Tac-Toe
# 2024-09-20 15:16:02,413 - INFO - Successfully processed: bweisiger15_Tic-Tac-Toe
# 2024-09-20 15:16:02,417 - INFO - Created output directory: E:\Repositories\Summary_Analysis\c-mars_future.sample
# 2024-09-20 15:16:02,417 - INFO - Processing repository: c-mars_future.sample
# 2024-09-20 15:16:02,420 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\c-mars_future.sample -o E:\Repositories\Summary_Analysis\c-mars_future.sample
# 2024-09-20 15:16:10,527 - INFO - Successfully processed: c-mars_future.sample
# 2024-09-20 15:16:10,528 - INFO - Created output directory: E:\Repositories\Summary_Analysis\caseyjames_myJavaProjects
# 2024-09-20 15:16:10,531 - INFO - Processing repository: caseyjames_myJavaProjects
# 2024-09-20 15:16:10,533 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\caseyjames_myJavaProjects -o E:\Repositories\Summary_Analysis\caseyjames_myJavaProjects
# 2024-09-20 15:16:38,961 - INFO - Successfully processed: caseyjames_myJavaProjects
# 2024-09-20 15:16:39,057 - INFO - Created output directory: E:\Repositories\Summary_Analysis\catoenm_E-MERGE
# 2024-09-20 15:16:39,058 - INFO - Processing repository: catoenm_E-MERGE
# 2024-09-20 15:16:39,061 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\catoenm_E-MERGE -o E:\Repositories\Summary_Analysis\catoenm_E-MERGE
# 2024-09-20 15:16:51,342 - INFO - Successfully processed: catoenm_E-MERGE
# 2024-09-20 15:16:51,355 - INFO - Created output directory: E:\Repositories\Summary_Analysis\codylerum_simple-identity
# 2024-09-20 15:16:51,357 - INFO - Processing repository: codylerum_simple-identity
# 2024-09-20 15:16:51,362 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\codylerum_simple-identity -o E:\Repositories\Summary_Analysis\codylerum_simple-identity
# 2024-09-20 15:17:10,225 - INFO - Successfully processed: codylerum_simple-identity
# 2024-09-20 15:17:10,245 - INFO - Created output directory: E:\Repositories\Summary_Analysis\Complexible_stardog-spring
# 2024-09-20 15:17:10,249 - INFO - Processing repository: Complexible_stardog-spring
# 2024-09-20 15:17:10,252 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\Complexible_stardog-spring -o E:\Repositories\Summary_Analysis\Complexible_stardog-spring
# 2024-09-20 15:17:30,396 - INFO - Successfully processed: Complexible_stardog-spring
# 2024-09-20 15:17:30,403 - INFO - Created output directory: E:\Repositories\Summary_Analysis\coronalabs_plugins-source-google-iap-v3
# 2024-09-20 15:17:30,406 - INFO - Processing repository: coronalabs_plugins-source-google-iap-v3
# 2024-09-20 15:17:30,409 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\coronalabs_plugins-source-google-iap-v3 -o E:\Repositories\Summary_Analysis\coronalabs_plugins-source-google-iap-v3
# 2024-09-20 15:17:44,021 - INFO - Successfully processed: coronalabs_plugins-source-google-iap-v3
# 2024-09-20 15:17:44,030 - INFO - Created output directory: E:\Repositories\Summary_Analysis\coronalabs_plugins-source-native-popup-social
# 2024-09-20 15:17:44,034 - INFO - Processing repository: coronalabs_plugins-source-native-popup-social
# 2024-09-20 15:17:44,038 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\coronalabs_plugins-source-native-popup-social -o E:\Repositories\Summary_Analysis\coronalabs_plugins-source-native-popup-social
# 2024-09-20 15:17:53,014 - INFO - Successfully processed: coronalabs_plugins-source-native-popup-social
# 2024-09-20 15:17:53,018 - INFO - Created output directory: E:\Repositories\Summary_Analysis\coronalabs_plugins-source-pasteboard
# 2024-09-20 15:17:53,020 - INFO - Processing repository: coronalabs_plugins-source-pasteboard
# 2024-09-20 15:17:53,020 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\coronalabs_plugins-source-pasteboard -o E:\Repositories\Summary_Analysis\coronalabs_plugins-source-pasteboard
# 2024-09-20 15:17:58,068 - INFO - Successfully processed: coronalabs_plugins-source-pasteboard
# 2024-09-20 15:17:58,074 - INFO - Created output directory: E:\Repositories\Summary_Analysis\crazytaxi_wastebin
# 2024-09-20 15:17:58,075 - INFO - Processing repository: crazytaxi_wastebin
# 2024-09-20 15:17:58,078 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\crazytaxi_wastebin -o E:\Repositories\Summary_Analysis\crazytaxi_wastebin
# 2024-09-20 15:18:03,497 - INFO - Successfully processed: crazytaxi_wastebin
# 2024-09-20 15:18:03,500 - INFO - Created output directory: E:\Repositories\Summary_Analysis\CXgamer_MC-ticker
# 2024-09-20 15:18:03,503 - INFO - Processing repository: CXgamer_MC-ticker
# 2024-09-20 15:18:03,504 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\CXgamer_MC-ticker -o E:\Repositories\Summary_Analysis\CXgamer_MC-ticker
# 2024-09-20 15:18:53,544 - INFO - Successfully processed: CXgamer_MC-ticker
# 2024-09-20 15:18:53,546 - INFO - Created output directory: E:\Repositories\Summary_Analysis\DanyTlaw_Haggis
# 2024-09-20 15:18:53,547 - INFO - Processing repository: DanyTlaw_Haggis
# 2024-09-20 15:18:53,548 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\DanyTlaw_Haggis -o E:\Repositories\Summary_Analysis\DanyTlaw_Haggis
# 2024-09-20 15:19:06,364 - INFO - Successfully processed: DanyTlaw_Haggis
# 2024-09-20 15:19:06,372 - INFO - Created output directory: E:\Repositories\Summary_Analysis\dcapwell_jmh-tests
# 2024-09-20 15:19:06,375 - INFO - Processing repository: dcapwell_jmh-tests
# 2024-09-20 15:19:06,376 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\dcapwell_jmh-tests -o E:\Repositories\Summary_Analysis\dcapwell_jmh-tests
# 2024-09-20 15:19:16,973 - INFO - Successfully processed: dcapwell_jmh-tests
# 2024-09-20 15:19:16,977 - INFO - Created output directory: E:\Repositories\Summary_Analysis\DeyAbhishek_Web-Development-Projects
# 2024-09-20 15:19:16,979 - INFO - Processing repository: DeyAbhishek_Web-Development-Projects
# 2024-09-20 15:19:16,982 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\DeyAbhishek_Web-Development-Projects -o E:\Repositories\Summary_Analysis\DeyAbhishek_Web-Development-Projects
# 2024-09-20 15:19:34,824 - INFO - Successfully processed: DeyAbhishek_Web-Development-Projects
# 2024-09-20 15:19:34,827 - INFO - Created output directory: E:\Repositories\Summary_Analysis\EduardoCalle_ServiceBoot
# 2024-09-20 15:19:34,827 - INFO - Processing repository: EduardoCalle_ServiceBoot
# 2024-09-20 15:19:34,830 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\EduardoCalle_ServiceBoot -o E:\Repositories\Summary_Analysis\EduardoCalle_ServiceBoot
# 2024-09-20 15:19:43,550 - INFO - Successfully processed: EduardoCalle_ServiceBoot
# 2024-09-20 15:19:43,553 - INFO - Created output directory: E:\Repositories\Summary_Analysis\ftes_de.ftes.uon.seng2200.pa2
# 2024-09-20 15:19:43,555 - INFO - Processing repository: ftes_de.ftes.uon.seng2200.pa2
# 2024-09-20 15:19:43,557 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\ftes_de.ftes.uon.seng2200.pa2 -o E:\Repositories\Summary_Analysis\ftes_de.ftes.uon.seng2200.pa2
# 2024-09-20 15:19:57,542 - INFO - Successfully processed: ftes_de.ftes.uon.seng2200.pa2
# 2024-09-20 15:19:57,550 - INFO - Created output directory: E:\Repositories\Summary_Analysis\huntdog1541_theoryhomework1
# 2024-09-20 15:19:57,552 - INFO - Processing repository: huntdog1541_theoryhomework1
# 2024-09-20 15:19:57,555 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\huntdog1541_theoryhomework1 -o E:\Repositories\Summary_Analysis\huntdog1541_theoryhomework1
# 2024-09-20 15:20:04,269 - INFO - Successfully processed: huntdog1541_theoryhomework1
# 2024-09-20 15:20:04,271 - INFO - Created output directory: E:\Repositories\Summary_Analysis\icol2006_appCSV
# 2024-09-20 15:20:04,271 - INFO - Processing repository: icol2006_appCSV
# 2024-09-20 15:20:04,274 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\icol2006_appCSV -o E:\Repositories\Summary_Analysis\icol2006_appCSV
# 2024-09-20 15:20:12,305 - INFO - Successfully processed: icol2006_appCSV
# 2024-09-20 15:20:12,307 - INFO - Created output directory: E:\Repositories\Summary_Analysis\IMORALESNW_HealthyApp
# 2024-09-20 15:20:12,312 - INFO - Processing repository: IMORALESNW_HealthyApp
# 2024-09-20 15:20:12,314 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\IMORALESNW_HealthyApp -o E:\Repositories\Summary_Analysis\IMORALESNW_HealthyApp
# 2024-09-20 15:20:21,714 - INFO - Successfully processed: IMORALESNW_HealthyApp
# 2024-09-20 15:20:21,717 - INFO - Created output directory: E:\Repositories\Summary_Analysis\insoo078_kobis-utils
# 2024-09-20 15:20:21,719 - INFO - Processing repository: insoo078_kobis-utils
# 2024-09-20 15:20:21,722 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\insoo078_kobis-utils -o E:\Repositories\Summary_Analysis\insoo078_kobis-utils
# 2024-09-20 15:21:14,130 - INFO - Successfully processed: insoo078_kobis-utils
# 2024-09-20 15:21:14,136 - INFO - Created output directory: E:\Repositories\Summary_Analysis\Jarcionek_MTG-Deck-Builder
# 2024-09-20 15:21:14,138 - INFO - Processing repository: Jarcionek_MTG-Deck-Builder
# 2024-09-20 15:21:14,139 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\Jarcionek_MTG-Deck-Builder -o E:\Repositories\Summary_Analysis\Jarcionek_MTG-Deck-Builder
# 2024-09-20 15:21:37,056 - INFO - Successfully processed: Jarcionek_MTG-Deck-Builder
# 2024-09-20 15:21:37,058 - INFO - Created output directory: E:\Repositories\Summary_Analysis\JCDias_CadastroUsuarios
# 2024-09-20 15:21:37,058 - INFO - Processing repository: JCDias_CadastroUsuarios
# 2024-09-20 15:21:37,061 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\JCDias_CadastroUsuarios -o E:\Repositories\Summary_Analysis\JCDias_CadastroUsuarios
# 2024-09-20 15:21:51,793 - INFO - Successfully processed: JCDias_CadastroUsuarios
# 2024-09-20 15:21:51,796 - INFO - Created output directory: E:\Repositories\Summary_Analysis\jclayton23_Java
# 2024-09-20 15:21:51,797 - INFO - Processing repository: jclayton23_Java
# 2024-09-20 15:21:51,798 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\jclayton23_Java -o E:\Repositories\Summary_Analysis\jclayton23_Java
# 2024-09-20 15:21:59,321 - INFO - Successfully processed: jclayton23_Java
# 2024-09-20 15:21:59,355 - INFO - Created output directory: E:\Repositories\Summary_Analysis\jfeinstein10_SlidingMenu
# 2024-09-20 15:21:59,357 - INFO - Processing repository: jfeinstein10_SlidingMenu
# 2024-09-20 15:21:59,360 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\jfeinstein10_SlidingMenu -o E:\Repositories\Summary_Analysis\jfeinstein10_SlidingMenu
# 2024-09-20 15:22:23,532 - INFO - Successfully processed: jfeinstein10_SlidingMenu
# 2024-09-20 15:22:23,546 - INFO - Created output directory: E:\Repositories\Summary_Analysis\jipson7_sortingComparison-ScalaVsJava
# 2024-09-20 15:22:23,552 - INFO - Processing repository: jipson7_sortingComparison-ScalaVsJava
# 2024-09-20 15:22:23,558 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\jipson7_sortingComparison-ScalaVsJava -o E:\Repositories\Summary_Analysis\jipson7_sortingComparison-ScalaVsJava
# 2024-09-20 15:22:31,660 - INFO - Successfully processed: jipson7_sortingComparison-ScalaVsJava
# 2024-09-20 15:22:31,664 - INFO - Created output directory: E:\Repositories\Summary_Analysis\JPII_sandbox
# 2024-09-20 15:22:31,664 - INFO - Processing repository: JPII_sandbox
# 2024-09-20 15:22:31,664 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\JPII_sandbox -o E:\Repositories\Summary_Analysis\JPII_sandbox
# 2024-09-20 15:22:48,577 - INFO - Successfully processed: JPII_sandbox
# 2024-09-20 15:22:48,581 - INFO - Created output directory: E:\Repositories\Summary_Analysis\JsonHunt_mobile-app-scaffolding
# 2024-09-20 15:22:48,585 - INFO - Processing repository: JsonHunt_mobile-app-scaffolding
# 2024-09-20 15:22:48,589 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\JsonHunt_mobile-app-scaffolding -o E:\Repositories\Summary_Analysis\JsonHunt_mobile-app-scaffolding
# 2024-09-20 15:23:20,563 - INFO - Successfully processed: JsonHunt_mobile-app-scaffolding
# 2024-09-20 15:23:20,682 - INFO - Created output directory: E:\Repositories\Summary_Analysis\JvalantPatel_AvailabilityManager
# 2024-09-20 15:23:20,684 - INFO - Processing repository: JvalantPatel_AvailabilityManager
# 2024-09-20 15:23:20,685 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\JvalantPatel_AvailabilityManager -o E:\Repositories\Summary_Analysis\JvalantPatel_AvailabilityManager
# 2024-09-20 15:23:32,708 - INFO - Successfully processed: JvalantPatel_AvailabilityManager
# 2024-09-20 15:23:32,716 - INFO - Created output directory: E:\Repositories\Summary_Analysis\kennethlim206_wordFrequencyCalculator
# 2024-09-20 15:23:32,721 - INFO - Processing repository: kennethlim206_wordFrequencyCalculator
# 2024-09-20 15:23:32,723 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\kennethlim206_wordFrequencyCalculator -o E:\Repositories\Summary_Analysis\kennethlim206_wordFrequencyCalculator
# 2024-09-20 15:23:42,890 - INFO - Successfully processed: kennethlim206_wordFrequencyCalculator
# 2024-09-20 15:23:42,895 - INFO - Created output directory: E:\Repositories\Summary_Analysis\kennethlim206_worldFrequencyCalculator
# 2024-09-20 15:23:42,896 - INFO - Processing repository: kennethlim206_worldFrequencyCalculator
# 2024-09-20 15:23:42,898 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\kennethlim206_worldFrequencyCalculator -o E:\Repositories\Summary_Analysis\kennethlim206_worldFrequencyCalculator
# 2024-09-20 15:23:53,168 - INFO - Successfully processed: kennethlim206_worldFrequencyCalculator
# 2024-09-20 15:23:53,177 - INFO - Created output directory: E:\Repositories\Summary_Analysis\klcathy_CS144
# 2024-09-20 15:23:53,181 - INFO - Processing repository: klcathy_CS144
# 2024-09-20 15:23:53,185 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\klcathy_CS144 -o E:\Repositories\Summary_Analysis\klcathy_CS144
# 2024-09-20 15:24:06,668 - INFO - Successfully processed: klcathy_CS144
# 2024-09-20 15:24:06,671 - INFO - Created output directory: E:\Repositories\Summary_Analysis\kutala_z_test
# 2024-09-20 15:24:06,672 - INFO - Processing repository: kutala_z_test
# 2024-09-20 15:24:06,674 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\kutala_z_test -o E:\Repositories\Summary_Analysis\kutala_z_test
# 2024-09-20 15:24:13,989 - INFO - Successfully processed: kutala_z_test
# 2024-09-20 15:24:13,998 - INFO - Created output directory: E:\Repositories\Summary_Analysis\LingZhong_thesis
# 2024-09-20 15:24:14,001 - INFO - Processing repository: LingZhong_thesis
# 2024-09-20 15:24:14,004 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\LingZhong_thesis -o E:\Repositories\Summary_Analysis\LingZhong_thesis
# 2024-09-20 15:24:41,633 - INFO - Successfully processed: LingZhong_thesis
# 2024-09-20 15:24:41,715 - INFO - Created output directory: E:\Repositories\Summary_Analysis\MagIciaNGTAO_leetcode
# 2024-09-20 15:24:41,719 - INFO - Processing repository: MagIciaNGTAO_leetcode
# 2024-09-20 15:24:41,723 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\MagIciaNGTAO_leetcode -o E:\Repositories\Summary_Analysis\MagIciaNGTAO_leetcode
# 2024-09-20 15:25:15,101 - INFO - Successfully processed: MagIciaNGTAO_leetcode
# 2024-09-20 15:25:15,110 - INFO - Created output directory: E:\Repositories\Summary_Analysis\marcsstevenson_OvenSimCordova
# 2024-09-20 15:25:15,113 - INFO - Processing repository: marcsstevenson_OvenSimCordova
# 2024-09-20 15:25:15,116 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\marcsstevenson_OvenSimCordova -o E:\Repositories\Summary_Analysis\marcsstevenson_OvenSimCordova
# 2024-09-20 15:25:51,323 - INFO - Successfully processed: marcsstevenson_OvenSimCordova
# 2024-09-20 15:25:51,330 - INFO - Created output directory: E:\Repositories\Summary_Analysis\markcwal_TwitterClient
# 2024-09-20 15:25:51,330 - INFO - Processing repository: markcwal_TwitterClient
# 2024-09-20 15:25:51,335 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\markcwal_TwitterClient -o E:\Repositories\Summary_Analysis\markcwal_TwitterClient
# 2024-09-20 15:26:01,296 - INFO - Successfully processed: markcwal_TwitterClient
# 2024-09-20 15:26:01,306 - INFO - Created output directory: E:\Repositories\Summary_Analysis\mateobossio_Seguimiento-Disciplinario
# 2024-09-20 15:26:01,313 - INFO - Processing repository: mateobossio_Seguimiento-Disciplinario
# 2024-09-20 15:26:01,317 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\mateobossio_Seguimiento-Disciplinario -o E:\Repositories\Summary_Analysis\mateobossio_Seguimiento-Disciplinario
# 2024-09-20 15:26:11,603 - INFO - Successfully processed: mateobossio_Seguimiento-Disciplinario
# 2024-09-20 15:26:11,608 - INFO - Created output directory: E:\Repositories\Summary_Analysis\mathewreny_ARM230Compiler
# 2024-09-20 15:26:11,610 - INFO - Processing repository: mathewreny_ARM230Compiler
# 2024-09-20 15:26:11,611 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\mathewreny_ARM230Compiler -o E:\Repositories\Summary_Analysis\mathewreny_ARM230Compiler
# 2024-09-20 15:26:35,426 - INFO - Successfully processed: mathewreny_ARM230Compiler
# 2024-09-20 15:26:35,433 - INFO - Created output directory: E:\Repositories\Summary_Analysis\MavenDevoxxFR2015_demos
# 2024-09-20 15:26:35,438 - INFO - Processing repository: MavenDevoxxFR2015_demos
# 2024-09-20 15:26:35,443 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\MavenDevoxxFR2015_demos -o E:\Repositories\Summary_Analysis\MavenDevoxxFR2015_demos
# 2024-09-20 15:26:45,425 - INFO - Successfully processed: MavenDevoxxFR2015_demos
# 2024-09-20 15:26:45,429 - INFO - Created output directory: E:\Repositories\Summary_Analysis\maxdemarzi_archetype_api
# 2024-09-20 15:26:45,431 - INFO - Processing repository: maxdemarzi_archetype_api
# 2024-09-20 15:26:45,433 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\maxdemarzi_archetype_api -o E:\Repositories\Summary_Analysis\maxdemarzi_archetype_api
# 2024-09-20 15:27:02,619 - INFO - Successfully processed: maxdemarzi_archetype_api
# 2024-09-20 15:27:02,628 - INFO - Created output directory: E:\Repositories\Summary_Analysis\McCraftaholics_WarpPortals-AnalyticsServer
# 2024-09-20 15:27:02,630 - INFO - Processing repository: McCraftaholics_WarpPortals-AnalyticsServer
# 2024-09-20 15:27:02,633 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\McCraftaholics_WarpPortals-AnalyticsServer -o E:\Repositories\Summary_Analysis\McCraftaholics_WarpPortals-AnalyticsServer
# 2024-09-20 15:27:16,655 - INFO - Successfully processed: McCraftaholics_WarpPortals-AnalyticsServer
# 2024-09-20 15:27:16,660 - INFO - Created output directory: E:\Repositories\Summary_Analysis\miguelslemos_Ecommerce
# 2024-09-20 15:27:16,663 - INFO - Processing repository: miguelslemos_Ecommerce
# 2024-09-20 15:27:16,669 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\miguelslemos_Ecommerce -o E:\Repositories\Summary_Analysis\miguelslemos_Ecommerce
# 2024-09-20 15:27:27,043 - INFO - Successfully processed: miguelslemos_Ecommerce
# 2024-09-20 15:27:27,048 - INFO - Created output directory: E:\Repositories\Summary_Analysis\mit09_my-mapreduce
# 2024-09-20 15:27:27,050 - INFO - Processing repository: mit09_my-mapreduce
# 2024-09-20 15:27:27,053 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\mit09_my-mapreduce -o E:\Repositories\Summary_Analysis\mit09_my-mapreduce
# 2024-09-20 15:27:54,543 - INFO - Successfully processed: mit09_my-mapreduce
# 2024-09-20 15:27:54,545 - INFO - Created output directory: E:\Repositories\Summary_Analysis\mk12_mycraft
# 2024-09-20 15:27:54,550 - INFO - Processing repository: mk12_mycraft
# 2024-09-20 15:27:54,552 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\mk12_mycraft -o E:\Repositories\Summary_Analysis\mk12_mycraft
# 2024-09-20 15:29:56,980 - INFO - Successfully processed: mk12_mycraft
# 2024-09-20 15:29:57,097 - INFO - Created output directory: E:\Repositories\Summary_Analysis\NCIP_c3pr-docs
# 2024-09-20 15:29:57,102 - INFO - Processing repository: NCIP_c3pr-docs
# 2024-09-20 15:29:57,107 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\NCIP_c3pr-docs -o E:\Repositories\Summary_Analysis\NCIP_c3pr-docs
# 2024-09-20 15:30:49,185 - INFO - Successfully processed: NCIP_c3pr-docs
# 2024-09-20 15:30:49,206 - INFO - Created output directory: E:\Repositories\Summary_Analysis\neureal_noo4j-core
# 2024-09-20 15:30:49,211 - INFO - Processing repository: neureal_noo4j-core
# 2024-09-20 15:30:49,214 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\neureal_noo4j-core -o E:\Repositories\Summary_Analysis\neureal_noo4j-core
# 2024-09-20 15:31:07,782 - INFO - Successfully processed: neureal_noo4j-core
# 2024-09-20 15:31:07,795 - INFO - Created output directory: E:\Repositories\Summary_Analysis\neureal_noo4j-daemon
# 2024-09-20 15:31:07,803 - INFO - Processing repository: neureal_noo4j-daemon
# 2024-09-20 15:31:07,811 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\neureal_noo4j-daemon -o E:\Repositories\Summary_Analysis\neureal_noo4j-daemon
# 2024-09-20 15:31:19,988 - INFO - Successfully processed: neureal_noo4j-daemon
# 2024-09-20 15:31:19,991 - INFO - Created output directory: E:\Repositories\Summary_Analysis\ngladitz_emma
# 2024-09-20 15:31:19,993 - INFO - Processing repository: ngladitz_emma
# 2024-09-20 15:31:19,996 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\ngladitz_emma -o E:\Repositories\Summary_Analysis\ngladitz_emma
# 2024-09-20 15:32:28,448 - INFO - Successfully processed: ngladitz_emma
# 2024-09-20 15:32:28,461 - INFO - Created output directory: E:\Repositories\Summary_Analysis\nikit-cpp_VkCachingPlayer
# 2024-09-20 15:32:28,463 - INFO - Processing repository: nikit-cpp_VkCachingPlayer
# 2024-09-20 15:32:28,474 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\nikit-cpp_VkCachingPlayer -o E:\Repositories\Summary_Analysis\nikit-cpp_VkCachingPlayer
# 2024-09-20 15:32:44,316 - INFO - Successfully processed: nikit-cpp_VkCachingPlayer
# 2024-09-20 15:32:44,327 - INFO - Created output directory: E:\Repositories\Summary_Analysis\noelmkawano_digits
# 2024-09-20 15:32:44,335 - INFO - Processing repository: noelmkawano_digits
# 2024-09-20 15:32:44,344 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\noelmkawano_digits -o E:\Repositories\Summary_Analysis\noelmkawano_digits
# 2024-09-20 15:32:54,551 - INFO - Successfully processed: noelmkawano_digits
# 2024-09-20 15:32:54,559 - INFO - Created output directory: E:\Repositories\Summary_Analysis\panzb_my_repository
# 2024-09-20 15:32:54,564 - INFO - Processing repository: panzb_my_repository
# 2024-09-20 15:32:54,571 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\panzb_my_repository -o E:\Repositories\Summary_Analysis\panzb_my_repository
# 2024-09-20 15:32:59,481 - INFO - Successfully processed: panzb_my_repository
# 2024-09-20 15:32:59,486 - INFO - Created output directory: E:\Repositories\Summary_Analysis\POMStrap_pomstrap3
# 2024-09-20 15:32:59,489 - INFO - Processing repository: POMStrap_pomstrap3
# 2024-09-20 15:32:59,495 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\POMStrap_pomstrap3 -o E:\Repositories\Summary_Analysis\POMStrap_pomstrap3
# 2024-09-20 15:33:11,143 - INFO - Successfully processed: POMStrap_pomstrap3
# 2024-09-20 15:33:11,148 - INFO - Created output directory: E:\Repositories\Summary_Analysis\prachiyshah_CoreNettyProject
# 2024-09-20 15:33:11,151 - INFO - Processing repository: prachiyshah_CoreNettyProject
# 2024-09-20 15:33:11,153 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\prachiyshah_CoreNettyProject -o E:\Repositories\Summary_Analysis\prachiyshah_CoreNettyProject
# 2024-09-20 15:33:51,108 - INFO - Successfully processed: prachiyshah_CoreNettyProject
# 2024-09-20 15:33:51,119 - INFO - Created output directory: E:\Repositories\Summary_Analysis\pritamkesh_AccelerometerProject
# 2024-09-20 15:33:51,125 - INFO - Processing repository: pritamkesh_AccelerometerProject
# 2024-09-20 15:33:51,128 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\pritamkesh_AccelerometerProject -o E:\Repositories\Summary_Analysis\pritamkesh_AccelerometerProject
# 2024-09-20 15:34:02,397 - INFO - Successfully processed: pritamkesh_AccelerometerProject
# 2024-09-20 15:34:02,499 - INFO - Created output directory: E:\Repositories\Summary_Analysis\pszabolcs_canvasandroid
# 2024-09-20 15:34:02,504 - INFO - Processing repository: pszabolcs_canvasandroid
# 2024-09-20 15:34:02,509 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\pszabolcs_canvasandroid -o E:\Repositories\Summary_Analysis\pszabolcs_canvasandroid
# 2024-09-20 15:34:28,121 - INFO - Successfully processed: pszabolcs_canvasandroid
# 2024-09-20 15:34:28,131 - INFO - Created output directory: E:\Repositories\Summary_Analysis\PunchApp_volley
# 2024-09-20 15:34:28,136 - INFO - Processing repository: PunchApp_volley
# 2024-09-20 15:34:28,145 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\PunchApp_volley -o E:\Repositories\Summary_Analysis\PunchApp_volley
# 2024-09-20 15:34:55,370 - INFO - Successfully processed: PunchApp_volley
# 2024-09-20 15:34:55,381 - INFO - Created output directory: E:\Repositories\Summary_Analysis\QuantumBadger_RedReader
# 2024-09-20 15:34:55,386 - INFO - Processing repository: QuantumBadger_RedReader
# 2024-09-20 15:34:55,388 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\QuantumBadger_RedReader -o E:\Repositories\Summary_Analysis\QuantumBadger_RedReader
# 2024-09-20 15:36:57,891 - INFO - Successfully processed: QuantumBadger_RedReader
# 2024-09-20 15:36:57,927 - INFO - Created output directory: E:\Repositories\Summary_Analysis\rilsikane_dlt-nrct
# 2024-09-20 15:36:57,931 - INFO - Processing repository: rilsikane_dlt-nrct
# 2024-09-20 15:36:57,937 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\rilsikane_dlt-nrct -o E:\Repositories\Summary_Analysis\rilsikane_dlt-nrct
# 2024-09-20 15:37:59,025 - INFO - Successfully processed: rilsikane_dlt-nrct
# 2024-09-20 15:37:59,155 - INFO - Created output directory: E:\Repositories\Summary_Analysis\rmsor_waa_practice
# 2024-09-20 15:37:59,162 - INFO - Processing repository: rmsor_waa_practice
# 2024-09-20 15:37:59,172 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\rmsor_waa_practice -o E:\Repositories\Summary_Analysis\rmsor_waa_practice
# 2024-09-20 15:38:42,303 - INFO - Successfully processed: rmsor_waa_practice
# 2024-09-20 15:38:42,324 - INFO - Created output directory: E:\Repositories\Summary_Analysis\Shanmathi1_MSGSP-implementation
# 2024-09-20 15:38:42,329 - INFO - Processing repository: Shanmathi1_MSGSP-implementation
# 2024-09-20 15:38:42,334 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\Shanmathi1_MSGSP-implementation -o E:\Repositories\Summary_Analysis\Shanmathi1_MSGSP-implementation
# 2024-09-20 15:38:51,430 - INFO - Successfully processed: Shanmathi1_MSGSP-implementation
# 2024-09-20 15:38:51,433 - INFO - Created output directory: E:\Repositories\Summary_Analysis\si-yao_chat-room
# 2024-09-20 15:38:51,435 - INFO - Processing repository: si-yao_chat-room
# 2024-09-20 15:38:51,437 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\si-yao_chat-room -o E:\Repositories\Summary_Analysis\si-yao_chat-room
# 2024-09-20 15:38:59,793 - INFO - Successfully processed: si-yao_chat-room
# 2024-09-20 15:38:59,799 - INFO - Created output directory: E:\Repositories\Summary_Analysis\spininertia_w2v4j
# 2024-09-20 15:38:59,804 - INFO - Processing repository: spininertia_w2v4j
# 2024-09-20 15:38:59,806 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\spininertia_w2v4j -o E:\Repositories\Summary_Analysis\spininertia_w2v4j
# 2024-09-20 15:39:09,669 - INFO - Successfully processed: spininertia_w2v4j
# 2024-09-20 15:39:09,684 - INFO - Created output directory: E:\Repositories\Summary_Analysis\springprojects_spring-boot-showcase
# 2024-09-20 15:39:09,687 - INFO - Processing repository: springprojects_spring-boot-showcase
# 2024-09-20 15:39:09,691 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\springprojects_spring-boot-showcase -o E:\Repositories\Summary_Analysis\springprojects_spring-boot-showcase
# 2024-09-20 15:39:21,244 - INFO - Successfully processed: springprojects_spring-boot-showcase
# 2024-09-20 15:39:21,252 - INFO - Created output directory: E:\Repositories\Summary_Analysis\sskjames_simpleopenlpimporter
# 2024-09-20 15:39:21,257 - INFO - Processing repository: sskjames_simpleopenlpimporter
# 2024-09-20 15:39:21,260 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\sskjames_simpleopenlpimporter -o E:\Repositories\Summary_Analysis\sskjames_simpleopenlpimporter
# 2024-09-20 15:39:28,397 - INFO - Successfully processed: sskjames_simpleopenlpimporter
# 2024-09-20 15:39:28,402 - INFO - Created output directory: E:\Repositories\Summary_Analysis\sskjames_tamilunicodeconverter
# 2024-09-20 15:39:28,404 - INFO - Processing repository: sskjames_tamilunicodeconverter
# 2024-09-20 15:39:28,405 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\sskjames_tamilunicodeconverter -o E:\Repositories\Summary_Analysis\sskjames_tamilunicodeconverter
# 2024-09-20 15:39:35,849 - INFO - Successfully processed: sskjames_tamilunicodeconverter
# 2024-09-20 15:39:35,854 - INFO - Created output directory: E:\Repositories\Summary_Analysis\stefanil_JFXControls
# 2024-09-20 15:39:35,856 - INFO - Processing repository: stefanil_JFXControls
# 2024-09-20 15:39:35,861 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\stefanil_JFXControls -o E:\Repositories\Summary_Analysis\stefanil_JFXControls
# 2024-09-20 15:39:54,956 - INFO - Successfully processed: stefanil_JFXControls
# 2024-09-20 15:39:54,970 - INFO - Created output directory: E:\Repositories\Summary_Analysis\stephensanchez_familiar
# 2024-09-20 15:39:54,977 - INFO - Processing repository: stephensanchez_familiar
# 2024-09-20 15:39:54,981 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\stephensanchez_familiar -o E:\Repositories\Summary_Analysis\stephensanchez_familiar
# 2024-09-20 15:40:03,132 - INFO - Successfully processed: stephensanchez_familiar
# 2024-09-20 15:40:03,142 - INFO - Created output directory: E:\Repositories\Summary_Analysis\Stuv7CB_opticlabGUI
# 2024-09-20 15:40:03,146 - INFO - Processing repository: Stuv7CB_opticlabGUI
# 2024-09-20 15:40:03,154 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\Stuv7CB_opticlabGUI -o E:\Repositories\Summary_Analysis\Stuv7CB_opticlabGUI
# 2024-09-20 15:40:12,554 - INFO - Successfully processed: Stuv7CB_opticlabGUI
# 2024-09-20 15:40:12,581 - INFO - Created output directory: E:\Repositories\Summary_Analysis\Superjisan_Stormy
# 2024-09-20 15:40:12,582 - INFO - Processing repository: Superjisan_Stormy
# 2024-09-20 15:40:12,584 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\Superjisan_Stormy -o E:\Repositories\Summary_Analysis\Superjisan_Stormy
# 2024-09-20 15:40:19,381 - INFO - Successfully processed: Superjisan_Stormy
# 2024-09-20 15:40:19,384 - INFO - Created output directory: E:\Repositories\Summary_Analysis\TechplexEngineer_OmniNode
# 2024-09-20 15:40:19,387 - INFO - Processing repository: TechplexEngineer_OmniNode
# 2024-09-20 15:40:19,387 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\TechplexEngineer_OmniNode -o E:\Repositories\Summary_Analysis\TechplexEngineer_OmniNode
# 2024-09-20 15:40:28,046 - INFO - Successfully processed: TechplexEngineer_OmniNode
# 2024-09-20 15:40:28,053 - INFO - Created output directory: E:\Repositories\Summary_Analysis\tecnomatico_AsistenciaTecnomatica
# 2024-09-20 15:40:28,055 - INFO - Processing repository: tecnomatico_AsistenciaTecnomatica
# 2024-09-20 15:40:28,057 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\tecnomatico_AsistenciaTecnomatica -o E:\Repositories\Summary_Analysis\tecnomatico_AsistenciaTecnomatica
# 2024-09-20 15:40:45,869 - INFO - Successfully processed: tecnomatico_AsistenciaTecnomatica
# 2024-09-20 15:40:45,881 - INFO - Created output directory: E:\Repositories\Summary_Analysis\tgibbons-students-css_VogellaDatabaseAsg10Start
# 2024-09-20 15:40:45,888 - INFO - Processing repository: tgibbons-students-css_VogellaDatabaseAsg10Start
# 2024-09-20 15:40:45,896 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\tgibbons-students-css_VogellaDatabaseAsg10Start -o E:\Repositories\Summary_Analysis\tgibbons-students-css_VogellaDatabaseAsg10Start
# 2024-09-20 15:40:53,416 - INFO - Successfully processed: tgibbons-students-css_VogellaDatabaseAsg10Start
# 2024-09-20 15:40:53,434 - INFO - Created output directory: E:\Repositories\Summary_Analysis\The-WUUSTER_Randoms
# 2024-09-20 15:40:53,439 - INFO - Processing repository: The-WUUSTER_Randoms
# 2024-09-20 15:40:53,442 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\The-WUUSTER_Randoms -o E:\Repositories\Summary_Analysis\The-WUUSTER_Randoms
# 2024-09-20 15:41:01,358 - INFO - Successfully processed: The-WUUSTER_Randoms
# 2024-09-20 15:41:01,363 - INFO - Created output directory: E:\Repositories\Summary_Analysis\thiguetta_elastiky-framework
# 2024-09-20 15:41:01,368 - INFO - Processing repository: thiguetta_elastiky-framework
# 2024-09-20 15:41:01,374 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\thiguetta_elastiky-framework -o E:\Repositories\Summary_Analysis\thiguetta_elastiky-framework
# 2024-09-20 15:41:09,124 - INFO - Successfully processed: thiguetta_elastiky-framework
# 2024-09-20 15:41:09,129 - INFO - Created output directory: E:\Repositories\Summary_Analysis\Tibolte_ElasticDownload
# 2024-09-20 15:41:09,129 - INFO - Processing repository: Tibolte_ElasticDownload
# 2024-09-20 15:41:09,131 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\Tibolte_ElasticDownload -o E:\Repositories\Summary_Analysis\Tibolte_ElasticDownload
# 2024-09-20 15:41:21,005 - INFO - Successfully processed: Tibolte_ElasticDownload
# 2024-09-20 15:41:21,019 - INFO - Created output directory: E:\Repositories\Summary_Analysis\Trololoshe4ki_Forest
# 2024-09-20 15:41:21,026 - INFO - Processing repository: Trololoshe4ki_Forest
# 2024-09-20 15:41:21,034 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\Trololoshe4ki_Forest -o E:\Repositories\Summary_Analysis\Trololoshe4ki_Forest
# 2024-09-20 15:41:28,975 - INFO - Successfully processed: Trololoshe4ki_Forest
# 2024-09-20 15:41:28,986 - INFO - Created output directory: E:\Repositories\Summary_Analysis\tsinux_JavaSE
# 2024-09-20 15:41:28,991 - INFO - Processing repository: tsinux_JavaSE
# 2024-09-20 15:41:28,996 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\tsinux_JavaSE -o E:\Repositories\Summary_Analysis\tsinux_JavaSE
# 2024-09-20 15:41:41,444 - INFO - Successfully processed: tsinux_JavaSE
# 2024-09-20 15:41:41,452 - INFO - Created output directory: E:\Repositories\Summary_Analysis\TymchenkoIvan_study
# 2024-09-20 15:41:41,454 - INFO - Processing repository: TymchenkoIvan_study
# 2024-09-20 15:41:41,457 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\TymchenkoIvan_study -o E:\Repositories\Summary_Analysis\TymchenkoIvan_study
# 2024-09-20 15:42:05,212 - INFO - Successfully processed: TymchenkoIvan_study
# 2024-09-20 15:42:05,219 - INFO - Created output directory: E:\Repositories\Summary_Analysis\UniTime_cpsolver
# 2024-09-20 15:42:05,223 - INFO - Processing repository: UniTime_cpsolver
# 2024-09-20 15:42:05,227 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\UniTime_cpsolver -o E:\Repositories\Summary_Analysis\UniTime_cpsolver
# 2024-09-20 15:44:13,534 - INFO - Successfully processed: UniTime_cpsolver
# 2024-09-20 15:44:13,858 - INFO - Created output directory: E:\Repositories\Summary_Analysis\vanevery_JSON-with-gson-Example
# 2024-09-20 15:44:13,861 - INFO - Processing repository: vanevery_JSON-with-gson-Example
# 2024-09-20 15:44:13,863 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\vanevery_JSON-with-gson-Example -o E:\Repositories\Summary_Analysis\vanevery_JSON-with-gson-Example
# 2024-09-20 15:44:24,274 - INFO - Successfully processed: vanevery_JSON-with-gson-Example
# 2024-09-20 15:44:24,280 - INFO - Created output directory: E:\Repositories\Summary_Analysis\wangjia55_CircleChooseDisc
# 2024-09-20 15:44:24,283 - INFO - Processing repository: wangjia55_CircleChooseDisc
# 2024-09-20 15:44:24,285 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\wangjia55_CircleChooseDisc -o E:\Repositories\Summary_Analysis\wangjia55_CircleChooseDisc
# 2024-09-20 15:44:33,775 - INFO - Successfully processed: wangjia55_CircleChooseDisc
# 2024-09-20 15:44:33,780 - INFO - Created output directory: E:\Repositories\Summary_Analysis\Welon5656_media-app-for-android
# 2024-09-20 15:44:33,785 - INFO - Processing repository: Welon5656_media-app-for-android
# 2024-09-20 15:44:33,788 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\Welon5656_media-app-for-android -o E:\Repositories\Summary_Analysis\Welon5656_media-app-for-android
# 2024-09-20 15:44:43,662 - INFO - Successfully processed: Welon5656_media-app-for-android
# 2024-09-20 15:44:43,676 - INFO - Created output directory: E:\Repositories\Summary_Analysis\wiki-w_google
# 2024-09-20 15:44:43,680 - INFO - Processing repository: wiki-w_google
# 2024-09-20 15:44:43,683 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\wiki-w_google -o E:\Repositories\Summary_Analysis\wiki-w_google
# 2024-09-20 15:45:26,048 - INFO - Successfully processed: wiki-w_google
# 2024-09-20 15:45:26,162 - INFO - Created output directory: E:\Repositories\Summary_Analysis\xinyu-liu_Car-Park-System
# 2024-09-20 15:45:26,168 - INFO - Processing repository: xinyu-liu_Car-Park-System
# 2024-09-20 15:45:26,177 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\xinyu-liu_Car-Park-System -o E:\Repositories\Summary_Analysis\xinyu-liu_Car-Park-System
# 2024-09-20 15:45:37,863 - INFO - Successfully processed: xinyu-liu_Car-Park-System
# 2024-09-20 15:45:37,873 - INFO - Created output directory: E:\Repositories\Summary_Analysis\yangqing0314_CircelProgressTime
# 2024-09-20 15:45:37,882 - INFO - Processing repository: yangqing0314_CircelProgressTime
# 2024-09-20 15:45:37,885 - INFO - Executing command: java -jar E:\DesigniteJava\DesigniteJava.jar -i E:\Repositories\Cloned_Reposit\yangqing0314_CircelProgressTime -o E:\Repositories\Summary_Analysis\yangqing0314_CircelProgressTime
# 2024-09-20 15:45:46,167 - INFO - Successfully processed: yangqing0314_CircelProgressTime
# 2024-09-20 15:45:46,172 - INFO - === All repositories have been processed. ===
